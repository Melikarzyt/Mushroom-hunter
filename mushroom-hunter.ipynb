# %%
import numpy as np
import pandas as pd

# %%
train_csv = pd.read_csv("train.csv")
train_csv
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        e         b           y         w       t    a               f
# 1        p         x           y         n       t    p               f
# 2        e         f           s         y       t    a               f
# 3        p         x           f         g       f    f               f
# 4        e         x           f         n       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 6494     p         x           y         g       f    f               f
# 6495     p         f           y         n       t    p               f
# 6496     e         x           s         w       f    n               f
# 6497     e         x           f         e       t    n               f
# 6498     p         f           s         b       t    f               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0               c         b          w  ...                        s
# 1               c         n          n  ...                        s
# 2               w         n          w  ...                        s
# 3               c         b          h  ...                        k
# 4               w         b          k  ...                        s
# ...           ...       ...        ...  ...                      ...
# 6494            c         b          p  ...                        k
# 6495            c         n          k  ...                        s
# 6496            w         b          n  ...                        f
# 6497            c         b          w  ...                        s
# 6498            c         b          p  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         p                      p         p          w
# 4                         w                      w         p          w
# ...                     ...                    ...       ...        ...
# 6494                      p                      b         p          w
# 6495                      w                      w         p          w
# 6496                      w                      w         p          w
# 6497                      p                      p         p          w
# 6498                      w                      w         p          w
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 k          s       m
# 1              o         p                 k          s       u
# 2              o         p                 n          v       d
# 3              o         l                 h          v       g
# 4              o         e                 k          s       g
# ...          ...       ...               ...        ...     ...
# 6494           o         l                 h          v       d
# 6495           o         p                 k          s       g
# 6496           o         e                 n          a       g
# 6497           o         p                 n          v       d
# 6498           o         p                 h          s       g
#
# [6499 rows x 23 columns]

# %%
test_csv = pd.read_csv("test.csv")
test_csv
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            x           f         n       t    n               f
# 1            x           f         w       f    n               f
# 2            x           f         g       f    n               f
# 3            f           f         g       t    n               f
# 4            x           y         e       t    n               f
# ...        ...         ...       ...     ...  ...             ...
# 1620         k           y         n       f    f               f
# 1621         f           y         n       f    y               f
# 1622         x           y         g       f    f               f
# 1623         x           s         w       t    f               f
# 1624         x           s         w       t    p               f
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               c         b          p           t  ...
# 1               w         b          n           t  ...
# 2               w         b          n           t  ...
# 3               c         b          u           t  ...
# 4               c         b          n           t  ...
# ...           ...       ...        ...         ...  ...
# 1620            c         n          b           t  ...
# 1621            c         n          b           t  ...
# 1622            c         b          p           e  ...
# 1623            c         b          p           t  ...
# 1624            c         n          p           e  ...
#
#      stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                           s                      g                      p
# 1                           f                      w                      w
# 2                           s                      w                      w
# 3                           s                      g                      w
# 4                           s                      p                      p
# ...                       ...                    ...                    ...
# 1620                        k                      w                      p
# 1621                        s                      p                      w
# 1622                        k                      b                      n
# 1623                        s                      w                      w
# 1624                        s                      w                      w
#
#      veil-type veil-color ring-number ring-type spore-print-color population  \
# 0            p          w           o         p                 k          y
# 1            p          w           o         e                 k          a
# 2            p          w           o         e                 k          a
# 3            p          w           o         p                 n          y
# 4            p          w           o         p                 n          v
# ...        ...        ...         ...       ...               ...        ...
# 1620         p          w           o         e                 w          v
# 1621         p          w           o         e                 w          v
# 1622         p          w           o         l                 h          v
# 1623         p          w           o         p                 h          s
# 1624         p          w           o         p                 n          v
#
#      habitat
# 0          d
# 1          g
# 2          g
# 3          d
# 4          d
# ...      ...
# 1620       d
# 1621       p
# 1622       p
# 1623       u
# 1624       g
#
# [1625 rows x 22 columns]

# %%
for col in train_csv.columns:
    print(col, train_csv[col].unique())
# Out:
# class ['e' 'p']
# cap-shape ['b' 'x' 'f' 'k' 's' 'c']
# cap-surface ['y' 's' 'f' 'g']
# cap-color ['w' 'n' 'y' 'g' 'e' 'c' 'p' 'b' 'u' 'r']
# bruises ['t' 'f']
# odor ['a' 'p' 'f' 'n' 'l' 's' 'y' 'm' 'c']
# gill-attachment ['f' 'a']
# gill-spacing ['c' 'w']
# gill-size ['b' 'n']
# gill-color ['w' 'n' 'h' 'k' 'b' 'g' 'p' 'u' 'e' 'y' 'o' 'r']
# stalk-shape ['e' 't']
# stalk-root ['c' 'e' 'b' '?' 'r']
# stalk-surface-above-ring ['s' 'k' 'f' 'y']
# stalk-surface-below-ring ['s' 'k' 'f' 'y']
# stalk-color-above-ring ['w' 'p' 'g' 'b' 'n' 'o' 'c' 'e' 'y']
# stalk-color-below-ring ['w' 'p' 'g' 'n' 'y' 'b' 'o' 'c' 'e']
# veil-type ['p']
# veil-color ['w' 'n' 'y' 'o']
# ring-number ['o' 't' 'n']
# ring-type ['p' 'l' 'e' 'n' 'f']
# spore-print-color ['k' 'n' 'h' 'w' 'o' 'r' 'y' 'b' 'u']
# population ['s' 'v' 'y' 'n' 'a' 'c']
# habitat ['m' 'u' 'd' 'g' 'l' 'p' 'w']

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
for col in train_csv.columns:
    train_csv[col] = encoder.fit_transform(train_csv[col])
